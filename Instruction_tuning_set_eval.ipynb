# %% [markdown]
# # Evaluate Luxembourgish instruction tuning set
#
# In this notebook, we evaluate the to English translated Luxembourgish instruction tuning set. We already got the scores for each row from Nvidia Nemotron 340b reward. We want to filter out low quality instruction-answer pairs based on correctness, helpfulness and coherence. We retain these 3 attributes to be the most important ones, as correct information is crucial for fine-tuning LLMs to prevent the generation of misleading or factual inaccurate responses. This will ensure the quality and reliablity of the fine-tuned model. The other important attribute being helpfulness, as the main purpose of LLM's is to assist users. Unhelpful answers, even if correct, are not contributing to the fine-tuning process. Filtering out unhelpful answers ensures that the model learns to generate useful and informative responses. Finally, ensuring coherence makes it that the model not only generates accurate and helpful, but also well-structured and easily followed answers, leading to a better user experience.

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# read in the sampled translated csv file
df = pd.read_csv('/content/drive/My Drive/Master Thesis/sampled_instruction_tuning_set_reward.csv')
df
# Out:
#                                            instruction  \
# 0                What is the brightest star in Dorado?
# 1    What happened to the Edict of Nantes, after He...
# 2    When did the devolution war start and how did ...
# 3                   When and where did Max Ophüls die?
# 4    What happened to the Schumacher building after...
# ..                                                 ...
# 195  Are there other opportunities to become politi...
# 196     When and where does the City Night Bus CN1 go?
# 197  What was the main topic of the consultations o...
# 198  What is the role of the hereditary grand ducal...
# 199             Who won the cup in basketball in 2004?
#
#                                               response  \
# 0    α Doradus, the brightest star in Dorado, is 20...
# 1    The Edict of Nantes was unfortunately not "per...
# 2    The war of devolution began in the spring of 1...
# 3        Max Ophüls died on March 26, 1957 in Hamburg.
# 4    The police museum of the non-profit organizati...
# ..                                                 ...
# 195  Yes, there are other opportunities to become p...
# 196  The City Night Bus CN1 goes from the Upper Tow...
# 197  The main topic was the refugee issue, especial...
# 198  We really live in very complicated times and y...
# 199  The Musel Pikes won the cup in basketball in 2...
#
#                                                   text  \
# 0    The following provides an instruction in the f...
# 1    The following provides an instruction in the f...
# 2    The following provides an instruction in the f...
# 3    The following provides an instruction in the f...
# 4    The following provides an instruction in the f...
# ..                                                 ...
# 195  The following provides an instruction in the f...
# 196  The following provides an instruction in the f...
# 197  The following provides an instruction in the f...
# 198  The following provides an instruction in the f...
# 199  The following provides an instruction in the f...
#
#                                         model_response
# 0    helpfulness:1.84375,correctness:1.6640625,cohe...
# 1    helpfulness:2.75,correctness:2.890625,coherenc...
# 2    helpfulness:2.578125,correctness:2.75,coherenc...
# 3    helpfulness:3.171875,correctness:3.21875,coher...
# 4    helpfulness:2.890625,correctness:3.078125,cohe...
# ..                                                 ...
# 195  helpfulness:2.328125,correctness:2.53125,coher...
# 196  helpfulness:0.94140625,correctness:1.0390625,c...
# 197  helpfulness:2.671875,correctness:2.671875,cohe...
# 198  helpfulness:1.171875,correctness:1.2734375,coh...
# 199  helpfulness:0.9921875,correctness:0.83984375,c...
#
# [200 rows x 4 columns]

# %% [markdown]
# # Convert scores to rows in dataframe

# %%
def extract_scores(s):
  scores = dict(x.split(':') for x in s.split(','))
  return float(scores['helpfulness']), float(scores['correctness']), float(scores['coherence']), float(scores['complexity']), float(scores['verbosity'])

# %%
df[['helpfulness', 'correctness', 'coherence', 'complexity', 'verbosity']] = df['model_response'].apply(extract_scores).apply(pd.Series)
df.drop(columns=['model_response'], inplace=True)
df
# Out:
#                                            instruction  \
# 0                What is the brightest star in Dorado?
# 1    What happened to the Edict of Nantes, after He...
# 2    When did the devolution war start and how did ...
# 3                   When and where did Max Ophüls die?
# 4    What happened to the Schumacher building after...
# ..                                                 ...
# 195  Are there other opportunities to become politi...
# 196     When and where does the City Night Bus CN1 go?
# 197  What was the main topic of the consultations o...
# 198  What is the role of the hereditary grand ducal...
# 199             Who won the cup in basketball in 2004?
#
#                                               response  \
# 0    α Doradus, the brightest star in Dorado, is 20...
# 1    The Edict of Nantes was unfortunately not "per...
# 2    The war of devolution began in the spring of 1...
# 3        Max Ophüls died on March 26, 1957 in Hamburg.
# 4    The police museum of the non-profit organizati...
# ..                                                 ...
# 195  Yes, there are other opportunities to become p...
# 196  The City Night Bus CN1 goes from the Upper Tow...
# 197  The main topic was the refugee issue, especial...
# 198  We really live in very complicated times and y...
# 199  The Musel Pikes won the cup in basketball in 2...
#
#                                                   text  helpfulness  \
# 0    The following provides an instruction in the f...     1.843750
# 1    The following provides an instruction in the f...     2.750000
# 2    The following provides an instruction in the f...     2.578125
# 3    The following provides an instruction in the f...     3.171875
# 4    The following provides an instruction in the f...     2.890625
# ..                                                 ...          ...
# 195  The following provides an instruction in the f...     2.328125
# 196  The following provides an instruction in the f...     0.941406
# 197  The following provides an instruction in the f...     2.671875
# 198  The following provides an instruction in the f...     1.171875
# 199  The following provides an instruction in the f...     0.992188
#
#      correctness  coherence  complexity  verbosity
# 0       1.664062   3.546875    1.007812   0.730469
# 1       2.890625   3.765625    1.117188   0.476562
# 2       2.750000   3.687500    1.117188   0.753906
# 3       3.218750   3.984375    0.667969   0.484375
# 4       3.078125   3.750000    1.140625   1.164062
# ..           ...        ...         ...        ...
# 195     2.531250   3.578125    0.933594   0.535156
# 196     1.039062   3.218750    0.511719   0.337891
# 197     2.671875   3.812500    0.667969   0.613281
# 198     1.273438   3.281250    0.695312   0.816406
# 199     0.839844   3.484375    0.386719   0.259766
#
# [200 rows x 8 columns]

# %%
#df.to_csv('/content/drive/My Drive/Master Thesis/sampled_instruction_tuning_set_reward_scores.csv', index=False)

# %% [markdown]
# # Filter out rows based on helpfulness, correctness and coherence
#
# According to Nvidia NIM (https://build.nvidia.com/nvidia/nemotron-4-340b-reward), the scores are as follows:
#
# * < 0.5 = very low
# * 0.5 - 1.5 = low
# * 1.5 - 2.5 = moderate
# * 2.5 - 3.5 = high
# * \> 3.5 = very high
#
# Hence, we want to get rid of all rows, who's helpfulness and correctness scores are lower than 2.5, as we only want keep high scored samples.

# %%
TRESHOLD_CORRECTNESS = 2.5
TRESHOLD_HELPFULNESS = 2.5
TRESHOLD_COHERENCE = 3.5

# %%
df_filtered = df[(df['correctness'] > TRESHOLD_CORRECTNESS) & (df['helpfulness'] > TRESHOLD_HELPFULNESS) & (df['coherence'] > TRESHOLD_COHERENCE)]
df_filtered
# Out:
#                                            instruction  \
# 1    What happened to the Edict of Nantes, after He...
# 2    When did the devolution war start and how did ...
# 3                   When and where did Max Ophüls die?
# 4    What happened to the Schumacher building after...
# 5    What are the essential amino acids? List the 9...
# ..                                                 ...
# 188  Enter the top 3 of the Eurovision Song Contest...
# 189  How many hectares of forest have burned in Por...
# 192  Give me the name of the first solo album of RO...
# 194  What is the opinion of the initiative Nee2015-...
# 197  What was the main topic of the consultations o...
#
#                                               response  \
# 1    The Edict of Nantes was unfortunately not "per...
# 2    The war of devolution began in the spring of 1...
# 3        Max Ophüls died on March 26, 1957 in Hamburg.
# 4    The police museum of the non-profit organizati...
# 5    The essential amino acids are: histidine, isol...
# ..                                                 ...
# 188  The top 3 were: 1. Sweden (Loreen) with 372 po...
# 189  Since the beginning of 2022, more than 30,000 ...
# 192  The first solo album of ROB THOMAS is SOMETHIN...
# 194  The Nee2015-Wee2050 initiative is of the opini...
# 197  The main topic was the refugee issue, especial...
#
#                                                   text  helpfulness  \
# 1    The following provides an instruction in the f...     2.750000
# 2    The following provides an instruction in the f...     2.578125
# 3    The following provides an instruction in the f...     3.171875
# 4    The following provides an instruction in the f...     2.890625
# 5    The following provides an instruction in the f...     3.468750
# ..                                                 ...          ...
# 188  The following provides an instruction in the f...     3.421875
# 189  The following provides an instruction in the f...     2.562500
# 192  The following provides an instruction in the f...     3.718750
# 194  The following provides an instruction in the f...     2.921875
# 197  The following provides an instruction in the f...     2.671875
#
#      correctness  coherence  complexity  verbosity
# 1       2.890625   3.765625    1.117188   0.476562
# 2       2.750000   3.687500    1.117188   0.753906
# 3       3.218750   3.984375    0.667969   0.484375
# 4       3.078125   3.750000    1.140625   1.164062
# 5       3.562500   3.859375    1.078125   0.769531
# ..           ...        ...         ...        ...
# 188     3.375000   3.968750    0.812500   1.000000
# 189     2.625000   3.843750    0.750000   0.574219
# 192     3.781250   3.875000    0.742188   0.871094
# 194     2.953125   3.703125    1.273438   0.941406
# 197     2.671875   3.812500    0.667969   0.613281
#
# [69 rows x 8 columns]

# %% [markdown]
# # Filter human evaluated data
#
# Now we want to check on our human evaluated dataset, which was evaluated based on helpfulness and coherence only. The scores were again given in a range from 0 to 4, but retaining integer scores for simplicity.

# %%
# !pip install openpyxl==3.1.2
# Out:
# Collecting openpyxl==3.1.2
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl==3.1.2) (1.1.0)
# Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 5.7 MB/s eta 0:00:00
# Installing collected packages: openpyxl
#   Attempting uninstall: openpyxl
#     Found existing installation: openpyxl 3.1.5
#     Uninstalling openpyxl-3.1.5:
#       Successfully uninstalled openpyxl-3.1.5
# Successfully installed openpyxl-3.1.2

# %%
df = pd.read_excel('/content/drive/My Drive/Master Thesis/human_evaluated_instruction_tuning_set_sampled.xlsx')
df
# Out:
#                                            instruction  \
# 0                What is the brightest star in Dorado?
# 1    What happened to the Edict of Nantes, after He...
# 2    When did the devolution war start and how did ...
# 3                   When and where did Max Ophüls die?
# 4    What happened to the Schumacher building after...
# ..                                                 ...
# 195  Are there other opportunities to become politi...
# 196     When and where does the City Night Bus CN1 go?
# 197  What was the main topic of the consultations o...
# 198  What is the role of the hereditary grand ducal...
# 199             Who won the cup in basketball in 2004?
#
#                                               response  helpfulness  coherence
# 0    α Doradus, the brightest star in Dorado, is 20...            3          3
# 1    The Edict of Nantes was unfortunately not "per...            1          0
# 2    The war of devolution began in the spring of 1...            2          2
# 3        Max Ophüls died on March 26, 1957 in Hamburg.            4          4
# 4    The police museum of the non-profit organizati...            3          4
# ..                                                 ...          ...        ...
# 195  Yes, there are other opportunities to become p...            4          4
# 196  The City Night Bus CN1 goes from the Upper Tow...            4          4
# 197  The main topic was the refugee issue, especial...            3          2
# 198  We really live in very complicated times and y...            0          1
# 199  The Musel Pikes won the cup in basketball in 2...            4          4
#
# [200 rows x 4 columns]

# %%
df_filtered = df[(df['helpfulness'] > TRESHOLD_HELPFULNESS-0.5) & (df['coherence'] > TRESHOLD_COHERENCE-0.5)]
df_filtered
# Out:
#                                            instruction  \
# 3                   When and where did Max Ophüls die?
# 4    What happened to the Schumacher building after...
# 6    Give me the names of the former municipalities...
# 7    Give me the area of the Polvermillen and what ...
# 9    How many films does the Cinémathèque de la Vil...
# ..                                                 ...
# 192  Give me the name of the first solo album of RO...
# 194  What is the opinion of the initiative Nee2015-...
# 195  Are there other opportunities to become politi...
# 196     When and where does the City Night Bus CN1 go?
# 199             Who won the cup in basketball in 2004?
#
#                                               response  helpfulness  coherence
# 3        Max Ophüls died on March 26, 1957 in Hamburg.            4          4
# 4    The police museum of the non-profit organizati...            3          4
# 6    The former municipalities of Beho, Bovigny, Ch...            4          4
# 7    The Polvermillen has an area of 24.82 ha, whic...            4          4
# 9    The Cinémathèque de la Ville de Luxembourg pro...            4          4
# ..                                                 ...          ...        ...
# 192  The first solo album of ROB THOMAS is SOMETHIN...            4          4
# 194  The Nee2015-Wee2050 initiative is of the opini...            4          4
# 195  Yes, there are other opportunities to become p...            4          4
# 196  The City Night Bus CN1 goes from the Upper Tow...            4          4
# 199  The Musel Pikes won the cup in basketball in 2...            4          4
#
# [103 rows x 4 columns]

# %%
df = pd.read_excel('/content/drive/My Drive/Master Thesis/sampled_instruction_tuning_set_human_eval_Lux.xlsx')
df
# Out:
#                                             human eval  \
# 0    I=1; R=1 (versteh aber nicht, warum 1 mal "de"...
# 1                                             I=1; R=0
# 2    I=1 (aber es heißt nicht "wann", sondern "wéin...
# 3                               I=1 (idem "wéini") R=1
# 4                                             I=1; R=1
# ..                                                 ...
# 195                                           I=1; R=1
# 196                                           I=1; R=1
# 197     I=1 (falscher Artikel); R=1 (falscher Artikel)
# 198                                           I=1; R=1
# 199                        I=1; R=1 (falscher Artikel)
#
#                                            instruction  \
# 0                   Wat ass de hellste Stär am Dorado?
# 1    Wat ass mam Edikt vun Nantes geschitt, nodeem ...
# 2    Wann huet de Devolutiounskrich ugefaangen a wé...
# 3            Wann an wou ass de Max Ophüls gestuerwen?
# 4    Wat ass mam Gebai vum Schumacher geschitt, nod...
# ..                                                 ...
# 195  Gëtt et och aner Méiglechkeeten fir politesch ...
# 196            Wann a wou fiert de City Night Bus CN1?
# 197  Wat war den Haaptthema vun de Berodunge vum Co...
# 198  Wat ass d'Rôle vun der ierfgroussherzoglecher ...
# 199  Wien huet déi Coupe am Basket am Joer 2004 gew...
#
#                                               response  \
# 0    Den α  Doradus, den hellste Stär am Dorado, as...
# 1    Den Edikt vun Nantes gouf leider net "perpétue...
# 2    De Devolutiounskrich huet am Fréijouer 1667 ug...
# 3    De Max Ophüls ass de 26. Mäerz 1957 zu Hamburg...
# 4    De Policemusée vun der Asbl 'Le musée de la po...
# ..                                                 ...
# 195  Jo, et gëtt och aner Méiglechkeeten fir polite...
# 196  De City Night Bus CN1 geet vun der Uewerstad i...
# 197  Den Haaptthema war d'Flüchtlingsproblematik, b...
# 198  Mir liewen wierklech a ganz komplizéierten Zäi...
# 199  Déi Musel Pikes hunn déi Coupe am Basket am Jo...
#
#                                                   text
# 0    The following provides an instruction in form ...
# 1    The following provides an instruction in form ...
# 2    The following provides an instruction in form ...
# 3    The following provides an instruction in form ...
# 4    The following provides an instruction in form ...
# ..                                                 ...
# 195  The following provides an instruction in form ...
# 196  The following provides an instruction in form ...
# 197  The following provides an instruction in form ...
# 198  The following provides an instruction in form ...
# 199  The following provides an instruction in form ...
#
# [200 rows x 4 columns]

# %% [markdown]
# We want to see, how many examples are deemed high quality by the human evaluator, where I=1 and R=1

# %%
df_filtered = df[df['human eval'].str.contains('I=1') == True]
df_filtered = df_filtered[df_filtered['human eval'].str.contains('R=1') == True]
df_filtered
# Out:
#                                             human eval  \
# 0    I=1; R=1 (versteh aber nicht, warum 1 mal "de"...
# 2    I=1 (aber es heißt nicht "wann", sondern "wéin...
# 3                               I=1 (idem "wéini") R=1
# 4                                             I=1; R=1
# 5    I=1 (aber "nimm op" würde ich so nicht sagen);...
# ..                                                 ...
# 195                                           I=1; R=1
# 196                                           I=1; R=1
# 197     I=1 (falscher Artikel); R=1 (falscher Artikel)
# 198                                           I=1; R=1
# 199                        I=1; R=1 (falscher Artikel)
#
#                                            instruction  \
# 0                   Wat ass de hellste Stär am Dorado?
# 2    Wann huet de Devolutiounskrich ugefaangen a wé...
# 3            Wann an wou ass de Max Ophüls gestuerwen?
# 4    Wat ass mam Gebai vum Schumacher geschitt, nod...
# 5    Wat sinn déi essenziell Aminosaieren? Nimm déi...
# ..                                                 ...
# 195  Gëtt et och aner Méiglechkeeten fir politesch ...
# 196            Wann a wou fiert de City Night Bus CN1?
# 197  Wat war den Haaptthema vun de Berodunge vum Co...
# 198  Wat ass d'Rôle vun der ierfgroussherzoglecher ...
# 199  Wien huet déi Coupe am Basket am Joer 2004 gew...
#
#                                               response  \
# 0    Den α  Doradus, den hellste Stär am Dorado, as...
# 2    De Devolutiounskrich huet am Fréijouer 1667 ug...
# 3    De Max Ophüls ass de 26. Mäerz 1957 zu Hamburg...
# 4    De Policemusée vun der Asbl 'Le musée de la po...
# 5    Déi essenziell Aminosaieren sinn: Histidin, Is...
# ..                                                 ...
# 195  Jo, et gëtt och aner Méiglechkeeten fir polite...
# 196  De City Night Bus CN1 geet vun der Uewerstad i...
# 197  Den Haaptthema war d'Flüchtlingsproblematik, b...
# 198  Mir liewen wierklech a ganz komplizéierten Zäi...
# 199  Déi Musel Pikes hunn déi Coupe am Basket am Jo...
#
#                                                   text
# 0    The following provides an instruction in form ...
# 2    The following provides an instruction in form ...
# 3    The following provides an instruction in form ...
# 4    The following provides an instruction in form ...
# 5    The following provides an instruction in form ...
# ..                                                 ...
# 195  The following provides an instruction in form ...
# 196  The following provides an instruction in form ...
# 197  The following provides an instruction in form ...
# 198  The following provides an instruction in form ...
# 199  The following provides an instruction in form ...
#
# [164 rows x 4 columns]
